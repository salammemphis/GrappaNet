# %% [markdown]
# ### GrappaNet, one of the great work on MRI reconstruction was published in 2020. We tried to implement it since code was not available.  The paper can be found here https://arxiv.org/pdf/1910.12325v4.pdf
#
# Our Dataset is small and acquired with different imaging conditions than fastMRI dataset. This example has been shown for MRIs acquired with 9 coils. Unlike GrappNet paper we have precalculated grappa weights and reused during training. However, Model was trained in eager mode and consumes significant amount of time and GPU Memory for each epoch. We trained our model on 80 GB Apollo GPU

# %% [markdown]
# ## Import libraries and Prepare Dataset

# %%
import random, h5py, os, glob, sys, time
import numpy as np
import matplotlib.pyplot as plt
from numpy import fft 
from medpy.io import save, load
from pygrappa import grappa,mdgrappa
import tensorflow as tf
from utils import estimate_mdgrappa_kernel, Grappa_recon, calculate_mask, comp_sub_kspace, comp_img, apply_kernel_weight

os.environ['HDF5_USE_FILE_LOCKING']='FALSE'
#assign MRI file locations
path_to_save_data="enter path here" 
input_mris = 'enter path here' # input data location
crop_size=(18,512,192)
channel=18 #9 coils-- real+imaginary components
file_pattern="rawdata*"
all_files=sorted(glob.glob(input_mris+file_pattern))

# %% [markdown]
# ## Estimate Grappa Weight for each MRI (K-space)

# %%
cnt=1
crop_size_2=(crop_size[0]/2,crop_size[1],crop_size[1])
last_mask=None
X_train=[]
Y_train=[]
grappa_wt=[]
grappa_p=[]

#iterate over all files in the input directory provided above
for mri_f in sorted(all_files[:70]):
    filename=os.path.basename(mri_f)
    filename=filename.replace(".h5","")
    with h5py.File(mri_f,'r') as f:

        k = f['kspace'][()]
        mrh = f['ismrmrd_header'][()]
        loopcoils=f.attrs['loopcoils']
        #sensitivity=f['sensitivity'][()]
        #referrence=f['reference'][()]
        nSL, nCh, nFE, nPE = k.shape
        
        mid=nPE//2
        start=mid-int(nPE*0.05)
        end=mid+int(nPE*0.05)
        
        
        #print(loopcoils)
        mask=0*k
        mask[:,:,:,start:end]=1
        mask=calculate_mask(nFE,nPE,0.1,4)## add you maskfunction here  
        last_mask=mask
        subsampled_k=k*mask
       
        for slices in range(nSL): 
            ref_img=np.zeros((nCh,nFE,nPE),dtype=np.float)
            sub_kspace=np.zeros((nCh*2,nFE,nPE),dtype=np.float)
            wt,ps=estimate_mdgrappa_kernel(kspace=subsampled_k[slices,:,:,:],calib=None, kernel_size=(5, 5),coil_axis=0) 
            for iCh in [0,1,2,3,4,5,6,7,8]:
                    ref_img[iCh,:,:]=abs(fft.fftshift(fft.ifft2(k[slices,iCh,:,:])))
                    sub_kspace[iCh,:,:]=subsampled_k[slices,iCh,:,:].real
                    sub_kspace[iCh+9,:,:]=subsampled_k[slices,iCh,:,:].imag
            X_train.append(list(comp_sub_kspace(sub_kspace,crop_size)))
            Y_train.append(list(comp_img(ref_img,(crop_size[0]//2,crop_size[1],crop_size[2]))))
            grappa_wt.append(wt)
            grappa_p.append(ps)
            #save(np.transpose(comp_img(sub_img),(2,1,0)),path+'scratch/'+filename+'_sub_'+str(slices)+".nrrd", use_compression=False)
            #save(np.transpose(comp_img(ref_img),(2,1,0)),path+'scratch/'+filename+'_ref_'+str(slices)+".nrrd", use_compression=False)
        print(cnt,filename,f.attrs['acquisition'],nSL, nCh, nFE, nPE,loopcoils,start,end,"grappa: ")
# Out:
# 1 rawdata_150001_T1 T1 128 9 504 183 [0 1] 82 100 grappa:

# %% [markdown]
# ## Save the MRIs and estimated weight since it takes long time

# %%
import pickle
Y_train=np.array(Y_train).astype(np.float32)
X_train=np.array(X_train).astype(np.float32)

np.save(path_to_save_data+"2d_trainig_grappaNet_data_PE_9colis.npy",X_train) #save data since you may need later
np.save(path_to_save_data+"2d_trainig_GT_grappaNet_data_PE_colis.npy",Y_train)
with open('grapp_wt.pickle', 'wb') as handle:
    pickle.dump(grappa_wt, handle, protocol=pickle.HIGHEST_PROTOCOL)
 
with open('grapp_hole.pickle', 'wb') as handle:
    pickle.dump(grappa_p, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Calculate RSS that will be used as reference

# %%
X_train = np.transpose(X_train,(0,2,3,1))
Y_rss=np.sqrt(np.sum(np.square(Y_train),axis=1))
Y_rss=Y_rss.astype(np.float32)
print(X_train.shape,Y_rss.shape)
# Out:
# (128, 512, 192, 18) (128, 512, 192)

# %% [markdown]
# ## Normalize the data

# %%
dims=X_train.shape
print(dims)
for i in range(dims[0]):
    for j in range(dims[3]):
        X_train[i,:,:,j]=X_train[i,:,:,j]/((np.max(X_train[i,:,:,j])-np.min(X_train[i,:,:,j]))+1e-10)

for i in range(dims[0]):
    Y_rss[i,:,:]=Y_rss[i,:,:]/((np.max(Y_rss[i,:,:])-np.min(Y_rss[i,:,:]))+1e-10)
# Out:
# (128, 512, 192, 18)

# %% [markdown]
# ## Split the data into train and Test.  10% used for Validation

# %%
x_train=X_train[0:int(X_train.shape[0]-X_train.shape[0]*0.1),:,:,:]
y_train=Y_rss[0:int(X_train.shape[0]-X_train.shape[0]*0.1),:,:]
x_test=X_train[int(X_train.shape[0]-X_train.shape[0]*0.1):,:,:,:]
y_test=Y_rss[int(X_train.shape[0]-X_train.shape[0]*0.1):,:,:]
y_test=np.reshape(y_test, (y_test.shape[0],512,192))
grappa_train_indx=np.array(range(0,int(X_train.shape[0]-X_train.shape[0]*0.1)),dtype=int)
grappa_test_indx=np.array(range(int(X_train.shape[0]-X_train.shape[0]*0.1),X_train.shape[0]),dtype=int)

# %% [markdown]
# ## visualize a sample to check everything looks ok

# %%
indx=50
ref_img=abs(fft.fftshift(fft.ifft2(x_train[index,:,:,:])))

fix, ax=plt.subplots(nrows=1,ncols=2,figsize=(6,10))
ax[0].imshow(x_train[indx,:,:,0],cmap='gray')
ax[1].imshow(Y_rss[indx,:,:],cmap='gray')

plt.show()

# %% [markdown]
# ## Build Model. The precalculated grappa weight will be used to eliminate redundant calculation.

# %%
import os, gc
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="0,1,2,3"
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2' 
#del model
model=None
gc.collect()

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras import layers
from tensorflow.keras.layers import Input,BatchNormalization, Activation,Conv2D,ZeroPadding2D,MaxPooling2D,Reshape, AveragePooling2D
from tensorflow.keras.layers import PReLU, LeakyReLU,add, Attention, Dropout, Lambda, ReLU
from tensorflow.keras import regularizers
from tensorflow.keras.layers import Conv2DTranspose, UpSampling2D
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Model
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.optimizers import Adam, RMSprop
import tensorflow_addons as tfa
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
kernel_size=(3,3)
lamda=0.001

@tf.function
def model_loss_ssim(y_true, y_pred):
    global lamda
    ssim_loss=0
    max_val=1.0
    if tf.reduce_max(y_pred)>1.0:
        max_val=tf.reduce_max(y_pred)
    ssim_loss=tf.math.abs(tf.reduce_mean(tf.image.ssim(img1=y_true, img2=y_pred,max_val=max_val,filter_size=3, filter_sigma=0.1)))
    l1_loss=lamda*tf.reduce_mean(tf.math.abs(y_true-y_pred))
    return 1-ssim_loss +l1_loss
    
def conv_block(ip, nfilters,drop_rate):
    
    layer_top = Conv2D(nfilters, (3,3), padding = "same")(ip)

    #layer_top =BatchNormalization()(layer_top)
    layer_top = tfa.layers.InstanceNormalization(axis=3,center=True, 
                                                 scale=True,beta_initializer="random_uniform",
                                                 gamma_initializer="random_uniform")(layer_top)
    res_model=ReLU()(layer_top)
    res_model=Dropout(drop_rate)(res_model)
    
    res_model = Conv2D(nfilters, (3,3), padding = "same")(res_model)
    res_model = tfa.layers.InstanceNormalization(axis=3, center=True, 
                                                 scale=True,beta_initializer="random_uniform",
                                                 gamma_initializer="random_uniform")(res_model)
    #res_model =BatchNormalization()(res_model)
    res_model=Dropout(drop_rate)(res_model)
    res_model=add([layer_top,res_model])
    res_model=ReLU()(res_model)
    return res_model

def encoder(inp,nlayers, nbasefilters, drop_rate):
    
    skip_layers=[]
    layers=inp
    for i in range(nlayers):
        layers=conv_block(layers,nbasefilters*2**i,drop_rate)
        skip_layers.append(layers)
        layers=MaxPooling2D((2,2))(layers)
    return layers, skip_layers


def decoder(inp,nlayers, nbasefilters,skip_layers, drop_rate):
    
    layers=inp
    for i in range(nlayers):
        layers=conv_block(layers,nbasefilters*(2**(nlayers-1-i)),drop_rate)
        layers=UpSampling2D(size=(2,2),  interpolation='bilinear')(layers)
        layers=add([layers,skip_layers.pop()])
    
    return layers


def create_gen(gen_ip, nlayers,nbasefilters,lambda_l, drop_rate):
    op, skip_layers = encoder(gen_ip,nlayers, nbasefilters,drop_rate)
    op=decoder(op,nlayers, nbasefilters,skip_layers,drop_rate)
    op = Conv2D(18, (3,3), padding = "same")(op)
    return op

def custom_data_consistency(tensors):
    output= tf.where(tf.greater_equal(tensors[0], 1), tensors[0], tensors[1])
    out_cmplx=tf.complex(output[:,:,:,0:9], output[:,:,:,9:18])
    ift_sig=tf.signal.fftshift(tf.signal.ifft2d(out_cmplx, name=None))
    real_p=tf.math.real(ift_sig)
    imag_p=tf.math.imag(ift_sig)
    comb=tf.concat(axis=-1,values=[real_p, imag_p])
    #print("here",output.get_shape(),ift_sig.get_shape(),real_p.get_shape(),comb.get_shape(),tensors[0].get_shape())
    return comb

def custom_data_consistency_2(tensors):
    out_cmplx=tf.complex(tensors[1][:,:,:,0:9], tensors[1][:,:,:,9:18])
    ft_sig=tf.signal.fftshift(tf.signal.fft2d(out_cmplx, name=None))
    real_p=tf.math.real(ft_sig)
    imag_p=tf.math.imag(ft_sig)
    comb=tf.concat(axis=-1,values=[real_p, imag_p])
    output= tf.where(tf.greater_equal(tensors[0], 1), tensors[0], comb)
    return output

def aux_Grappa_layer(tensor1, tensor2):
    global grappa_wt
    global grappa_p
    t1=tensor1.numpy()
    t2=tensor2.numpy()
    #print("max",np.max(t1),np.max(t2),print(t1.shape))

    x_train_cmplx_target=t2[:,:,:,0:9]+1j*t2[:,:,:,9:18]
    x_train_cmplx_target=np.transpose(x_train_cmplx_target,(0,3,1,2))
    l_grappa=[]
    for i in range(x_train_cmplx_target.shape[0]):
        res= apply_kernel_weight(kspace=x_train_cmplx_target[i],calib=None,
                                 kernel_size=(5, 5),coil_axis=0,
                                 weights=grappa_wt[int(t1[i][0])],P=grappa_p[int(t1[i][0])])
        res=np.transpose(res,(1,2,0))
        out_cmplx_real=tf.convert_to_tensor(res.real)
        out_cmplx_imag=tf.convert_to_tensor(res.imag)
        comb=tf.concat(axis=2,values=[out_cmplx_real, out_cmplx_imag])
        l_grappa.append(comb)
    b_grappa=tf.stack(l_grappa)
    #print("grappa",b_grappa.get_shape())
    return b_grappa
    

def Grappa_layer(tensor):
    #print(tensor[1].get_shape())
    out_tensor=tf.py_function(func=aux_Grappa_layer, inp=tensor, Tout=tf.float32)
    out_tensor.set_shape(tensor[1].get_shape())
    #print(out_tensor.get_shape())
    return out_tensor
    


def ift_RSS(tensor):
    cmplx_tensor=tf.complex(tensor[:,:,:,0:9], tensor[:,:,:,9:18])
    ift_sig=tf.signal.fftshift(tf.signal.ifft2d(cmplx_tensor, name=None))
    Y_rss=tf.math.sqrt(tf.math.reduce_sum(tf.square(tf.math.abs(ift_sig)),axis=3))
    
    return Y_rss


def build_model(input_shape,n_filter=32,n_depth=4,lamda=1,dropout_rate=0.05):

    #first pass
    input_layer=Input(shape=input_shape)
    input_layer_grappa_wt_indx=Input(shape=(1))
    kspace_u1=create_gen(input_layer,n_depth,n_filter,lamda,dropout_rate)
    data_con_layer= Lambda(custom_data_consistency, name="data_const_K_u1")([input_layer, kspace_u1])
    img_space_u1=create_gen(data_con_layer,n_depth,n_filter,lamda,dropout_rate)
    data_con_layer= Lambda(custom_data_consistency_2, name="data_const_K_u1_2")([input_layer, img_space_u1])
    grappa_recon_k=Lambda(Grappa_layer, name="data_const_K_2")([input_layer_grappa_wt_indx, data_con_layer])
    
    
    #second Pass
    kspace_u2=create_gen(grappa_recon_k,n_depth,n_filter,lamda,dropout_rate)
    data_con_layer= Lambda(custom_data_consistency, name="data_const_K_u2")([input_layer, kspace_u2])
    img_space_u2=create_gen(data_con_layer,n_depth,n_filter,lamda,dropout_rate)
    data_con_layer= Lambda(custom_data_consistency_2, name="data_const_K_u2_2")([input_layer, img_space_u2])
    
    #IFT+RSS
    data_con_layer= Lambda(ift_RSS, name="IFT_RSS")(data_con_layer)
    return Model(inputs=[input_layer,input_layer_grappa_wt_indx],outputs=data_con_layer)

# %% [markdown]
# ## Train Model. Model will be trained in eager mode

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, LearningRateScheduler 
from tensorflow.keras.callbacks import TensorBoard ,ReduceLROnPlateau, EarlyStopping
model_name="weights/model_grappaNet.h5"
def step_decay(epoch, initial_lrate, drop, epochs_drop):
    return initial_lrate * math.pow(drop, math.floor((1+epoch)/float(epochs_drop)))

def get_callbacks(model_file, learning_rate_drop=0.7,learning_rate_patience=7, verbosity=1):
    callbacks = list()
    #callbacks.append(TensorBoard(log_dir='weights/Graph', histogram_freq=0, write_graph=True, write_images=True))
    callbacks.append(ModelCheckpoint(model_file, save_best_only=True))
    callbacks.append(ReduceLROnPlateau(factor=learning_rate_drop, patience=learning_rate_patience,verbose=verbosity))
    callbacks.append(EarlyStopping(verbose=verbosity, patience=200))
    return callbacks

strategy = tf.distribute.MirroredStrategy()
with strategy.scope():
    input_shape=(512,192,18)
    epochs=1
    batch_size=8
    model=build_model(input_shape)
    metrics=tf.keras.metrics.RootMeanSquaredError()
    model.compile(loss=model_loss_ssim, optimizer= Adam(learning_rate=0.0003),metrics=[metrics])
    #model.compile(loss=model_loss_ssim, optimizer= RMSprop(learning_rate=0.0003),metrics=[metrics])

# %%
model.summary()
#del X_train
#del Y_train
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_7 (InputLayer)            [(None, 512, 192, 18 0
# __________________________________________________________________________________________________
# conv2d_204 (Conv2D)             (None, 512, 192, 32) 5216        input_7[0][0]
# __________________________________________________________________________________________________
# instance_normalization_192 (Ins (None, 512, 192, 32) 64          conv2d_204[0][0]
# __________________________________________________________________________________________________
# re_lu_192 (ReLU)                (None, 512, 192, 32) 0           instance_normalization_192[0][0]
# __________________________________________________________________________________________________
# dropout_192 (Dropout)           (None, 512, 192, 32) 0           re_lu_192[0][0]
# __________________________________________________________________________________________________
# conv2d_205 (Conv2D)             (None, 512, 192, 32) 9248        dropout_192[0][0]
# __________________________________________________________________________________________________
# instance_normalization_193 (Ins (None, 512, 192, 32) 64          conv2d_205[0][0]
# __________________________________________________________________________________________________
# dropout_193 (Dropout)           (None, 512, 192, 32) 0           instance_normalization_193[0][0]
# __________________________________________________________________________________________________
# add_144 (Add)                   (None, 512, 192, 32) 0           instance_normalization_192[0][0]
#                                                                  dropout_193[0][0]
# __________________________________________________________________________________________________
# re_lu_193 (ReLU)                (None, 512, 192, 32) 0           add_144[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_48 (MaxPooling2D) (None, 256, 96, 32)  0           re_lu_193[0][0]
# __________________________________________________________________________________________________
# conv2d_206 (Conv2D)             (None, 256, 96, 64)  18496       max_pooling2d_48[0][0]
# __________________________________________________________________________________________________
# instance_normalization_194 (Ins (None, 256, 96, 64)  128         conv2d_206[0][0]
# __________________________________________________________________________________________________
# re_lu_194 (ReLU)                (None, 256, 96, 64)  0           instance_normalization_194[0][0]
# __________________________________________________________________________________________________
# dropout_194 (Dropout)           (None, 256, 96, 64)  0           re_lu_194[0][0]
# __________________________________________________________________________________________________
# conv2d_207 (Conv2D)             (None, 256, 96, 64)  36928       dropout_194[0][0]
# __________________________________________________________________________________________________
# instance_normalization_195 (Ins (None, 256, 96, 64)  128         conv2d_207[0][0]
# __________________________________________________________________________________________________
# dropout_195 (Dropout)           (None, 256, 96, 64)  0           instance_normalization_195[0][0]
# __________________________________________________________________________________________________
# add_145 (Add)                   (None, 256, 96, 64)  0           instance_normalization_194[0][0]
#                                                                  dropout_195[0][0]
# __________________________________________________________________________________________________
# re_lu_195 (ReLU)                (None, 256, 96, 64)  0           add_145[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_49 (MaxPooling2D) (None, 128, 48, 64)  0           re_lu_195[0][0]
# __________________________________________________________________________________________________
# conv2d_208 (Conv2D)             (None, 128, 48, 128) 73856       max_pooling2d_49[0][0]
# __________________________________________________________________________________________________
# instance_normalization_196 (Ins (None, 128, 48, 128) 256         conv2d_208[0][0]
# __________________________________________________________________________________________________
# re_lu_196 (ReLU)                (None, 128, 48, 128) 0           instance_normalization_196[0][0]
# __________________________________________________________________________________________________
# dropout_196 (Dropout)           (None, 128, 48, 128) 0           re_lu_196[0][0]
# __________________________________________________________________________________________________
# conv2d_209 (Conv2D)             (None, 128, 48, 128) 147584      dropout_196[0][0]
# __________________________________________________________________________________________________
# instance_normalization_197 (Ins (None, 128, 48, 128) 256         conv2d_209[0][0]
# __________________________________________________________________________________________________
# dropout_197 (Dropout)           (None, 128, 48, 128) 0           instance_normalization_197[0][0]
# __________________________________________________________________________________________________
# add_146 (Add)                   (None, 128, 48, 128) 0           instance_normalization_196[0][0]
#                                                                  dropout_197[0][0]
# __________________________________________________________________________________________________
# re_lu_197 (ReLU)                (None, 128, 48, 128) 0           add_146[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_50 (MaxPooling2D) (None, 64, 24, 128)  0           re_lu_197[0][0]
# __________________________________________________________________________________________________
# conv2d_210 (Conv2D)             (None, 64, 24, 256)  295168      max_pooling2d_50[0][0]
# __________________________________________________________________________________________________
# instance_normalization_198 (Ins (None, 64, 24, 256)  512         conv2d_210[0][0]
# __________________________________________________________________________________________________
# re_lu_198 (ReLU)                (None, 64, 24, 256)  0           instance_normalization_198[0][0]
# __________________________________________________________________________________________________
# dropout_198 (Dropout)           (None, 64, 24, 256)  0           re_lu_198[0][0]
# __________________________________________________________________________________________________
# conv2d_211 (Conv2D)             (None, 64, 24, 256)  590080      dropout_198[0][0]
# __________________________________________________________________________________________________
# instance_normalization_199 (Ins (None, 64, 24, 256)  512         conv2d_211[0][0]
# __________________________________________________________________________________________________
# dropout_199 (Dropout)           (None, 64, 24, 256)  0           instance_normalization_199[0][0]
# __________________________________________________________________________________________________
# add_147 (Add)                   (None, 64, 24, 256)  0           instance_normalization_198[0][0]
#                                                                  dropout_199[0][0]
# __________________________________________________________________________________________________
# re_lu_199 (ReLU)                (None, 64, 24, 256)  0           add_147[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_51 (MaxPooling2D) (None, 32, 12, 256)  0           re_lu_199[0][0]
# __________________________________________________________________________________________________
# conv2d_212 (Conv2D)             (None, 32, 12, 256)  590080      max_pooling2d_51[0][0]
# __________________________________________________________________________________________________
# instance_normalization_200 (Ins (None, 32, 12, 256)  512         conv2d_212[0][0]
# __________________________________________________________________________________________________
# re_lu_200 (ReLU)                (None, 32, 12, 256)  0           instance_normalization_200[0][0]
# __________________________________________________________________________________________________
# dropout_200 (Dropout)           (None, 32, 12, 256)  0           re_lu_200[0][0]
# __________________________________________________________________________________________________
# conv2d_213 (Conv2D)             (None, 32, 12, 256)  590080      dropout_200[0][0]
# __________________________________________________________________________________________________
# instance_normalization_201 (Ins (None, 32, 12, 256)  512         conv2d_213[0][0]
# __________________________________________________________________________________________________
# dropout_201 (Dropout)           (None, 32, 12, 256)  0           instance_normalization_201[0][0]
# __________________________________________________________________________________________________
# add_148 (Add)                   (None, 32, 12, 256)  0           instance_normalization_200[0][0]
#                                                                  dropout_201[0][0]
# __________________________________________________________________________________________________
# re_lu_201 (ReLU)                (None, 32, 12, 256)  0           add_148[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_48 (UpSampling2D) (None, 64, 24, 256)  0           re_lu_201[0][0]
# __________________________________________________________________________________________________
# add_149 (Add)                   (None, 64, 24, 256)  0           up_sampling2d_48[0][0]
#                                                                  re_lu_199[0][0]
# __________________________________________________________________________________________________
# conv2d_214 (Conv2D)             (None, 64, 24, 128)  295040      add_149[0][0]
# __________________________________________________________________________________________________
# instance_normalization_202 (Ins (None, 64, 24, 128)  256         conv2d_214[0][0]
# __________________________________________________________________________________________________
# re_lu_202 (ReLU)                (None, 64, 24, 128)  0           instance_normalization_202[0][0]
# __________________________________________________________________________________________________
# dropout_202 (Dropout)           (None, 64, 24, 128)  0           re_lu_202[0][0]
# __________________________________________________________________________________________________
# conv2d_215 (Conv2D)             (None, 64, 24, 128)  147584      dropout_202[0][0]
# __________________________________________________________________________________________________
# instance_normalization_203 (Ins (None, 64, 24, 128)  256         conv2d_215[0][0]
# __________________________________________________________________________________________________
# dropout_203 (Dropout)           (None, 64, 24, 128)  0           instance_normalization_203[0][0]
# __________________________________________________________________________________________________
# add_150 (Add)                   (None, 64, 24, 128)  0           instance_normalization_202[0][0]
#                                                                  dropout_203[0][0]
# __________________________________________________________________________________________________
# re_lu_203 (ReLU)                (None, 64, 24, 128)  0           add_150[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_49 (UpSampling2D) (None, 128, 48, 128) 0           re_lu_203[0][0]
# __________________________________________________________________________________________________
# add_151 (Add)                   (None, 128, 48, 128) 0           up_sampling2d_49[0][0]
#                                                                  re_lu_197[0][0]
# __________________________________________________________________________________________________
# conv2d_216 (Conv2D)             (None, 128, 48, 64)  73792       add_151[0][0]
# __________________________________________________________________________________________________
# instance_normalization_204 (Ins (None, 128, 48, 64)  128         conv2d_216[0][0]
# __________________________________________________________________________________________________
# re_lu_204 (ReLU)                (None, 128, 48, 64)  0           instance_normalization_204[0][0]
# __________________________________________________________________________________________________
# dropout_204 (Dropout)           (None, 128, 48, 64)  0           re_lu_204[0][0]
# __________________________________________________________________________________________________
# conv2d_217 (Conv2D)             (None, 128, 48, 64)  36928       dropout_204[0][0]
# __________________________________________________________________________________________________
# instance_normalization_205 (Ins (None, 128, 48, 64)  128         conv2d_217[0][0]
# __________________________________________________________________________________________________
# dropout_205 (Dropout)           (None, 128, 48, 64)  0           instance_normalization_205[0][0]
# __________________________________________________________________________________________________
# add_152 (Add)                   (None, 128, 48, 64)  0           instance_normalization_204[0][0]
#                                                                  dropout_205[0][0]
# __________________________________________________________________________________________________
# re_lu_205 (ReLU)                (None, 128, 48, 64)  0           add_152[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_50 (UpSampling2D) (None, 256, 96, 64)  0           re_lu_205[0][0]
# __________________________________________________________________________________________________
# add_153 (Add)                   (None, 256, 96, 64)  0           up_sampling2d_50[0][0]
#                                                                  re_lu_195[0][0]
# __________________________________________________________________________________________________
# conv2d_218 (Conv2D)             (None, 256, 96, 32)  18464       add_153[0][0]
# __________________________________________________________________________________________________
# instance_normalization_206 (Ins (None, 256, 96, 32)  64          conv2d_218[0][0]
# __________________________________________________________________________________________________
# re_lu_206 (ReLU)                (None, 256, 96, 32)  0           instance_normalization_206[0][0]
# __________________________________________________________________________________________________
# dropout_206 (Dropout)           (None, 256, 96, 32)  0           re_lu_206[0][0]
# __________________________________________________________________________________________________
# conv2d_219 (Conv2D)             (None, 256, 96, 32)  9248        dropout_206[0][0]
# __________________________________________________________________________________________________
# instance_normalization_207 (Ins (None, 256, 96, 32)  64          conv2d_219[0][0]
# __________________________________________________________________________________________________
# dropout_207 (Dropout)           (None, 256, 96, 32)  0           instance_normalization_207[0][0]
# __________________________________________________________________________________________________
# add_154 (Add)                   (None, 256, 96, 32)  0           instance_normalization_206[0][0]
#                                                                  dropout_207[0][0]
# __________________________________________________________________________________________________
# re_lu_207 (ReLU)                (None, 256, 96, 32)  0           add_154[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_51 (UpSampling2D) (None, 512, 192, 32) 0           re_lu_207[0][0]
# __________________________________________________________________________________________________
# add_155 (Add)                   (None, 512, 192, 32) 0           up_sampling2d_51[0][0]
#                                                                  re_lu_193[0][0]
# __________________________________________________________________________________________________
# conv2d_220 (Conv2D)             (None, 512, 192, 18) 5202        add_155[0][0]
# __________________________________________________________________________________________________
# data_const_K_u1 (Lambda)        (None, 512, 192, 18) 0           input_7[0][0]
#                                                                  conv2d_220[0][0]
# __________________________________________________________________________________________________
# conv2d_221 (Conv2D)             (None, 512, 192, 32) 5216        data_const_K_u1[0][0]
# __________________________________________________________________________________________________
# instance_normalization_208 (Ins (None, 512, 192, 32) 64          conv2d_221[0][0]
# __________________________________________________________________________________________________
# re_lu_208 (ReLU)                (None, 512, 192, 32) 0           instance_normalization_208[0][0]
# __________________________________________________________________________________________________
# dropout_208 (Dropout)           (None, 512, 192, 32) 0           re_lu_208[0][0]
# __________________________________________________________________________________________________
# conv2d_222 (Conv2D)             (None, 512, 192, 32) 9248        dropout_208[0][0]
# __________________________________________________________________________________________________
# instance_normalization_209 (Ins (None, 512, 192, 32) 64          conv2d_222[0][0]
# __________________________________________________________________________________________________
# dropout_209 (Dropout)           (None, 512, 192, 32) 0           instance_normalization_209[0][0]
# __________________________________________________________________________________________________
# add_156 (Add)                   (None, 512, 192, 32) 0           instance_normalization_208[0][0]
#                                                                  dropout_209[0][0]
# __________________________________________________________________________________________________
# re_lu_209 (ReLU)                (None, 512, 192, 32) 0           add_156[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_52 (MaxPooling2D) (None, 256, 96, 32)  0           re_lu_209[0][0]
# __________________________________________________________________________________________________
# conv2d_223 (Conv2D)             (None, 256, 96, 64)  18496       max_pooling2d_52[0][0]
# __________________________________________________________________________________________________
# instance_normalization_210 (Ins (None, 256, 96, 64)  128         conv2d_223[0][0]
# __________________________________________________________________________________________________
# re_lu_210 (ReLU)                (None, 256, 96, 64)  0           instance_normalization_210[0][0]
# __________________________________________________________________________________________________
# dropout_210 (Dropout)           (None, 256, 96, 64)  0           re_lu_210[0][0]
# __________________________________________________________________________________________________
# conv2d_224 (Conv2D)             (None, 256, 96, 64)  36928       dropout_210[0][0]
# __________________________________________________________________________________________________
# instance_normalization_211 (Ins (None, 256, 96, 64)  128         conv2d_224[0][0]
# __________________________________________________________________________________________________
# dropout_211 (Dropout)           (None, 256, 96, 64)  0           instance_normalization_211[0][0]
# __________________________________________________________________________________________________
# add_157 (Add)                   (None, 256, 96, 64)  0           instance_normalization_210[0][0]
#                                                                  dropout_211[0][0]
# __________________________________________________________________________________________________
# re_lu_211 (ReLU)                (None, 256, 96, 64)  0           add_157[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_53 (MaxPooling2D) (None, 128, 48, 64)  0           re_lu_211[0][0]
# __________________________________________________________________________________________________
# conv2d_225 (Conv2D)             (None, 128, 48, 128) 73856       max_pooling2d_53[0][0]
# __________________________________________________________________________________________________
# instance_normalization_212 (Ins (None, 128, 48, 128) 256         conv2d_225[0][0]
# __________________________________________________________________________________________________
# re_lu_212 (ReLU)                (None, 128, 48, 128) 0           instance_normalization_212[0][0]
# __________________________________________________________________________________________________
# dropout_212 (Dropout)           (None, 128, 48, 128) 0           re_lu_212[0][0]
# __________________________________________________________________________________________________
# conv2d_226 (Conv2D)             (None, 128, 48, 128) 147584      dropout_212[0][0]
# __________________________________________________________________________________________________
# instance_normalization_213 (Ins (None, 128, 48, 128) 256         conv2d_226[0][0]
# __________________________________________________________________________________________________
# dropout_213 (Dropout)           (None, 128, 48, 128) 0           instance_normalization_213[0][0]
# __________________________________________________________________________________________________
# add_158 (Add)                   (None, 128, 48, 128) 0           instance_normalization_212[0][0]
#                                                                  dropout_213[0][0]
# __________________________________________________________________________________________________
# re_lu_213 (ReLU)                (None, 128, 48, 128) 0           add_158[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_54 (MaxPooling2D) (None, 64, 24, 128)  0           re_lu_213[0][0]
# __________________________________________________________________________________________________
# conv2d_227 (Conv2D)             (None, 64, 24, 256)  295168      max_pooling2d_54[0][0]
# __________________________________________________________________________________________________
# instance_normalization_214 (Ins (None, 64, 24, 256)  512         conv2d_227[0][0]
# __________________________________________________________________________________________________
# re_lu_214 (ReLU)                (None, 64, 24, 256)  0           instance_normalization_214[0][0]
# __________________________________________________________________________________________________
# dropout_214 (Dropout)           (None, 64, 24, 256)  0           re_lu_214[0][0]
# __________________________________________________________________________________________________
# conv2d_228 (Conv2D)             (None, 64, 24, 256)  590080      dropout_214[0][0]
# __________________________________________________________________________________________________
# instance_normalization_215 (Ins (None, 64, 24, 256)  512         conv2d_228[0][0]
# __________________________________________________________________________________________________
# dropout_215 (Dropout)           (None, 64, 24, 256)  0           instance_normalization_215[0][0]
# __________________________________________________________________________________________________
# add_159 (Add)                   (None, 64, 24, 256)  0           instance_normalization_214[0][0]
#                                                                  dropout_215[0][0]
# __________________________________________________________________________________________________
# re_lu_215 (ReLU)                (None, 64, 24, 256)  0           add_159[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_55 (MaxPooling2D) (None, 32, 12, 256)  0           re_lu_215[0][0]
# __________________________________________________________________________________________________
# conv2d_229 (Conv2D)             (None, 32, 12, 256)  590080      max_pooling2d_55[0][0]
# __________________________________________________________________________________________________
# instance_normalization_216 (Ins (None, 32, 12, 256)  512         conv2d_229[0][0]
# __________________________________________________________________________________________________
# re_lu_216 (ReLU)                (None, 32, 12, 256)  0           instance_normalization_216[0][0]
# __________________________________________________________________________________________________
# dropout_216 (Dropout)           (None, 32, 12, 256)  0           re_lu_216[0][0]
# __________________________________________________________________________________________________
# conv2d_230 (Conv2D)             (None, 32, 12, 256)  590080      dropout_216[0][0]
# __________________________________________________________________________________________________
# instance_normalization_217 (Ins (None, 32, 12, 256)  512         conv2d_230[0][0]
# __________________________________________________________________________________________________
# dropout_217 (Dropout)           (None, 32, 12, 256)  0           instance_normalization_217[0][0]
# __________________________________________________________________________________________________
# add_160 (Add)                   (None, 32, 12, 256)  0           instance_normalization_216[0][0]
#                                                                  dropout_217[0][0]
# __________________________________________________________________________________________________
# re_lu_217 (ReLU)                (None, 32, 12, 256)  0           add_160[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_52 (UpSampling2D) (None, 64, 24, 256)  0           re_lu_217[0][0]
# __________________________________________________________________________________________________
# add_161 (Add)                   (None, 64, 24, 256)  0           up_sampling2d_52[0][0]
#                                                                  re_lu_215[0][0]
# __________________________________________________________________________________________________
# conv2d_231 (Conv2D)             (None, 64, 24, 128)  295040      add_161[0][0]
# __________________________________________________________________________________________________
# instance_normalization_218 (Ins (None, 64, 24, 128)  256         conv2d_231[0][0]
# __________________________________________________________________________________________________
# re_lu_218 (ReLU)                (None, 64, 24, 128)  0           instance_normalization_218[0][0]
# __________________________________________________________________________________________________
# dropout_218 (Dropout)           (None, 64, 24, 128)  0           re_lu_218[0][0]
# __________________________________________________________________________________________________
# conv2d_232 (Conv2D)             (None, 64, 24, 128)  147584      dropout_218[0][0]
# __________________________________________________________________________________________________
# instance_normalization_219 (Ins (None, 64, 24, 128)  256         conv2d_232[0][0]
# __________________________________________________________________________________________________
# dropout_219 (Dropout)           (None, 64, 24, 128)  0           instance_normalization_219[0][0]
# __________________________________________________________________________________________________
# add_162 (Add)                   (None, 64, 24, 128)  0           instance_normalization_218[0][0]
#                                                                  dropout_219[0][0]
# __________________________________________________________________________________________________
# re_lu_219 (ReLU)                (None, 64, 24, 128)  0           add_162[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_53 (UpSampling2D) (None, 128, 48, 128) 0           re_lu_219[0][0]
# __________________________________________________________________________________________________
# add_163 (Add)                   (None, 128, 48, 128) 0           up_sampling2d_53[0][0]
#                                                                  re_lu_213[0][0]
# __________________________________________________________________________________________________
# conv2d_233 (Conv2D)             (None, 128, 48, 64)  73792       add_163[0][0]
# __________________________________________________________________________________________________
# instance_normalization_220 (Ins (None, 128, 48, 64)  128         conv2d_233[0][0]
# __________________________________________________________________________________________________
# re_lu_220 (ReLU)                (None, 128, 48, 64)  0           instance_normalization_220[0][0]
# __________________________________________________________________________________________________
# dropout_220 (Dropout)           (None, 128, 48, 64)  0           re_lu_220[0][0]
# __________________________________________________________________________________________________
# conv2d_234 (Conv2D)             (None, 128, 48, 64)  36928       dropout_220[0][0]
# __________________________________________________________________________________________________
# instance_normalization_221 (Ins (None, 128, 48, 64)  128         conv2d_234[0][0]
# __________________________________________________________________________________________________
# dropout_221 (Dropout)           (None, 128, 48, 64)  0           instance_normalization_221[0][0]
# __________________________________________________________________________________________________
# add_164 (Add)                   (None, 128, 48, 64)  0           instance_normalization_220[0][0]
#                                                                  dropout_221[0][0]
# __________________________________________________________________________________________________
# re_lu_221 (ReLU)                (None, 128, 48, 64)  0           add_164[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_54 (UpSampling2D) (None, 256, 96, 64)  0           re_lu_221[0][0]
# __________________________________________________________________________________________________
# add_165 (Add)                   (None, 256, 96, 64)  0           up_sampling2d_54[0][0]
#                                                                  re_lu_211[0][0]
# __________________________________________________________________________________________________
# conv2d_235 (Conv2D)             (None, 256, 96, 32)  18464       add_165[0][0]
# __________________________________________________________________________________________________
# instance_normalization_222 (Ins (None, 256, 96, 32)  64          conv2d_235[0][0]
# __________________________________________________________________________________________________
# re_lu_222 (ReLU)                (None, 256, 96, 32)  0           instance_normalization_222[0][0]
# __________________________________________________________________________________________________
# dropout_222 (Dropout)           (None, 256, 96, 32)  0           re_lu_222[0][0]
# __________________________________________________________________________________________________
# conv2d_236 (Conv2D)             (None, 256, 96, 32)  9248        dropout_222[0][0]
# __________________________________________________________________________________________________
# instance_normalization_223 (Ins (None, 256, 96, 32)  64          conv2d_236[0][0]
# __________________________________________________________________________________________________
# dropout_223 (Dropout)           (None, 256, 96, 32)  0           instance_normalization_223[0][0]
# __________________________________________________________________________________________________
# add_166 (Add)                   (None, 256, 96, 32)  0           instance_normalization_222[0][0]
#                                                                  dropout_223[0][0]
# __________________________________________________________________________________________________
# re_lu_223 (ReLU)                (None, 256, 96, 32)  0           add_166[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_55 (UpSampling2D) (None, 512, 192, 32) 0           re_lu_223[0][0]
# __________________________________________________________________________________________________
# add_167 (Add)                   (None, 512, 192, 32) 0           up_sampling2d_55[0][0]
#                                                                  re_lu_209[0][0]
# __________________________________________________________________________________________________
# conv2d_237 (Conv2D)             (None, 512, 192, 18) 5202        add_167[0][0]
# __________________________________________________________________________________________________
# input_8 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# data_const_K_u1_2 (Lambda)      (None, 512, 192, 18) 0           input_7[0][0]
#                                                                  conv2d_237[0][0]
# __________________________________________________________________________________________________
# data_const_K_2 (Lambda)         (None, 512, 192, 18) 0           input_8[0][0]
#                                                                  data_const_K_u1_2[0][0]
# __________________________________________________________________________________________________
# conv2d_238 (Conv2D)             (None, 512, 192, 32) 5216        data_const_K_2[0][0]
# __________________________________________________________________________________________________
# instance_normalization_224 (Ins (None, 512, 192, 32) 64          conv2d_238[0][0]
# __________________________________________________________________________________________________
# re_lu_224 (ReLU)                (None, 512, 192, 32) 0           instance_normalization_224[0][0]
# __________________________________________________________________________________________________
# dropout_224 (Dropout)           (None, 512, 192, 32) 0           re_lu_224[0][0]
# __________________________________________________________________________________________________
# conv2d_239 (Conv2D)             (None, 512, 192, 32) 9248        dropout_224[0][0]
# __________________________________________________________________________________________________
# instance_normalization_225 (Ins (None, 512, 192, 32) 64          conv2d_239[0][0]
# __________________________________________________________________________________________________
# dropout_225 (Dropout)           (None, 512, 192, 32) 0           instance_normalization_225[0][0]
# __________________________________________________________________________________________________
# add_168 (Add)                   (None, 512, 192, 32) 0           instance_normalization_224[0][0]
#                                                                  dropout_225[0][0]
# __________________________________________________________________________________________________
# re_lu_225 (ReLU)                (None, 512, 192, 32) 0           add_168[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_56 (MaxPooling2D) (None, 256, 96, 32)  0           re_lu_225[0][0]
# __________________________________________________________________________________________________
# conv2d_240 (Conv2D)             (None, 256, 96, 64)  18496       max_pooling2d_56[0][0]
# __________________________________________________________________________________________________
# instance_normalization_226 (Ins (None, 256, 96, 64)  128         conv2d_240[0][0]
# __________________________________________________________________________________________________
# re_lu_226 (ReLU)                (None, 256, 96, 64)  0           instance_normalization_226[0][0]
# __________________________________________________________________________________________________
# dropout_226 (Dropout)           (None, 256, 96, 64)  0           re_lu_226[0][0]
# __________________________________________________________________________________________________
# conv2d_241 (Conv2D)             (None, 256, 96, 64)  36928       dropout_226[0][0]
# __________________________________________________________________________________________________
# instance_normalization_227 (Ins (None, 256, 96, 64)  128         conv2d_241[0][0]
# __________________________________________________________________________________________________
# dropout_227 (Dropout)           (None, 256, 96, 64)  0           instance_normalization_227[0][0]
# __________________________________________________________________________________________________
# add_169 (Add)                   (None, 256, 96, 64)  0           instance_normalization_226[0][0]
#                                                                  dropout_227[0][0]
# __________________________________________________________________________________________________
# re_lu_227 (ReLU)                (None, 256, 96, 64)  0           add_169[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_57 (MaxPooling2D) (None, 128, 48, 64)  0           re_lu_227[0][0]
# __________________________________________________________________________________________________
# conv2d_242 (Conv2D)             (None, 128, 48, 128) 73856       max_pooling2d_57[0][0]
# __________________________________________________________________________________________________
# instance_normalization_228 (Ins (None, 128, 48, 128) 256         conv2d_242[0][0]
# __________________________________________________________________________________________________
# re_lu_228 (ReLU)                (None, 128, 48, 128) 0           instance_normalization_228[0][0]
# __________________________________________________________________________________________________
# dropout_228 (Dropout)           (None, 128, 48, 128) 0           re_lu_228[0][0]
# __________________________________________________________________________________________________
# conv2d_243 (Conv2D)             (None, 128, 48, 128) 147584      dropout_228[0][0]
# __________________________________________________________________________________________________
# instance_normalization_229 (Ins (None, 128, 48, 128) 256         conv2d_243[0][0]
# __________________________________________________________________________________________________
# dropout_229 (Dropout)           (None, 128, 48, 128) 0           instance_normalization_229[0][0]
# __________________________________________________________________________________________________
# add_170 (Add)                   (None, 128, 48, 128) 0           instance_normalization_228[0][0]
#                                                                  dropout_229[0][0]
# __________________________________________________________________________________________________
# re_lu_229 (ReLU)                (None, 128, 48, 128) 0           add_170[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_58 (MaxPooling2D) (None, 64, 24, 128)  0           re_lu_229[0][0]
# __________________________________________________________________________________________________
# conv2d_244 (Conv2D)             (None, 64, 24, 256)  295168      max_pooling2d_58[0][0]
# __________________________________________________________________________________________________
# instance_normalization_230 (Ins (None, 64, 24, 256)  512         conv2d_244[0][0]
# __________________________________________________________________________________________________
# re_lu_230 (ReLU)                (None, 64, 24, 256)  0           instance_normalization_230[0][0]
# __________________________________________________________________________________________________
# dropout_230 (Dropout)           (None, 64, 24, 256)  0           re_lu_230[0][0]
# __________________________________________________________________________________________________
# conv2d_245 (Conv2D)             (None, 64, 24, 256)  590080      dropout_230[0][0]
# __________________________________________________________________________________________________
# instance_normalization_231 (Ins (None, 64, 24, 256)  512         conv2d_245[0][0]
# __________________________________________________________________________________________________
# dropout_231 (Dropout)           (None, 64, 24, 256)  0           instance_normalization_231[0][0]
# __________________________________________________________________________________________________
# add_171 (Add)                   (None, 64, 24, 256)  0           instance_normalization_230[0][0]
#                                                                  dropout_231[0][0]
# __________________________________________________________________________________________________
# re_lu_231 (ReLU)                (None, 64, 24, 256)  0           add_171[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_59 (MaxPooling2D) (None, 32, 12, 256)  0           re_lu_231[0][0]
# __________________________________________________________________________________________________
# conv2d_246 (Conv2D)             (None, 32, 12, 256)  590080      max_pooling2d_59[0][0]
# __________________________________________________________________________________________________
# instance_normalization_232 (Ins (None, 32, 12, 256)  512         conv2d_246[0][0]
# __________________________________________________________________________________________________
# re_lu_232 (ReLU)                (None, 32, 12, 256)  0           instance_normalization_232[0][0]
# __________________________________________________________________________________________________
# dropout_232 (Dropout)           (None, 32, 12, 256)  0           re_lu_232[0][0]
# __________________________________________________________________________________________________
# conv2d_247 (Conv2D)             (None, 32, 12, 256)  590080      dropout_232[0][0]
# __________________________________________________________________________________________________
# instance_normalization_233 (Ins (None, 32, 12, 256)  512         conv2d_247[0][0]
# __________________________________________________________________________________________________
# dropout_233 (Dropout)           (None, 32, 12, 256)  0           instance_normalization_233[0][0]
# __________________________________________________________________________________________________
# add_172 (Add)                   (None, 32, 12, 256)  0           instance_normalization_232[0][0]
#                                                                  dropout_233[0][0]
# __________________________________________________________________________________________________
# re_lu_233 (ReLU)                (None, 32, 12, 256)  0           add_172[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_56 (UpSampling2D) (None, 64, 24, 256)  0           re_lu_233[0][0]
# ...
# __________________________________________________________________________________________________
# conv2d_258 (Conv2D)             (None, 256, 96, 64)  36928       dropout_242[0][0]
# __________________________________________________________________________________________________
# instance_normalization_243 (Ins (None, 256, 96, 64)  128         conv2d_258[0][0]
# __________________________________________________________________________________________________
# dropout_243 (Dropout)           (None, 256, 96, 64)  0           instance_normalization_243[0][0]
# __________________________________________________________________________________________________
# add_181 (Add)                   (None, 256, 96, 64)  0           instance_normalization_242[0][0]
#                                                                  dropout_243[0][0]
# __________________________________________________________________________________________________
# re_lu_243 (ReLU)                (None, 256, 96, 64)  0           add_181[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_61 (MaxPooling2D) (None, 128, 48, 64)  0           re_lu_243[0][0]
# __________________________________________________________________________________________________
# conv2d_259 (Conv2D)             (None, 128, 48, 128) 73856       max_pooling2d_61[0][0]
# __________________________________________________________________________________________________
# instance_normalization_244 (Ins (None, 128, 48, 128) 256         conv2d_259[0][0]
# __________________________________________________________________________________________________
# re_lu_244 (ReLU)                (None, 128, 48, 128) 0           instance_normalization_244[0][0]
# __________________________________________________________________________________________________
# dropout_244 (Dropout)           (None, 128, 48, 128) 0           re_lu_244[0][0]
# __________________________________________________________________________________________________
# conv2d_260 (Conv2D)             (None, 128, 48, 128) 147584      dropout_244[0][0]
# __________________________________________________________________________________________________
# instance_normalization_245 (Ins (None, 128, 48, 128) 256         conv2d_260[0][0]
# __________________________________________________________________________________________________
# dropout_245 (Dropout)           (None, 128, 48, 128) 0           instance_normalization_245[0][0]
# __________________________________________________________________________________________________
# add_182 (Add)                   (None, 128, 48, 128) 0           instance_normalization_244[0][0]
#                                                                  dropout_245[0][0]
# __________________________________________________________________________________________________
# re_lu_245 (ReLU)                (None, 128, 48, 128) 0           add_182[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_62 (MaxPooling2D) (None, 64, 24, 128)  0           re_lu_245[0][0]
# __________________________________________________________________________________________________
# conv2d_261 (Conv2D)             (None, 64, 24, 256)  295168      max_pooling2d_62[0][0]
# __________________________________________________________________________________________________
# instance_normalization_246 (Ins (None, 64, 24, 256)  512         conv2d_261[0][0]
# __________________________________________________________________________________________________
# re_lu_246 (ReLU)                (None, 64, 24, 256)  0           instance_normalization_246[0][0]
# __________________________________________________________________________________________________
# dropout_246 (Dropout)           (None, 64, 24, 256)  0           re_lu_246[0][0]
# __________________________________________________________________________________________________
# conv2d_262 (Conv2D)             (None, 64, 24, 256)  590080      dropout_246[0][0]
# __________________________________________________________________________________________________
# instance_normalization_247 (Ins (None, 64, 24, 256)  512         conv2d_262[0][0]
# __________________________________________________________________________________________________
# dropout_247 (Dropout)           (None, 64, 24, 256)  0           instance_normalization_247[0][0]
# __________________________________________________________________________________________________
# add_183 (Add)                   (None, 64, 24, 256)  0           instance_normalization_246[0][0]
#                                                                  dropout_247[0][0]
# __________________________________________________________________________________________________
# re_lu_247 (ReLU)                (None, 64, 24, 256)  0           add_183[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_63 (MaxPooling2D) (None, 32, 12, 256)  0           re_lu_247[0][0]
# __________________________________________________________________________________________________
# conv2d_263 (Conv2D)             (None, 32, 12, 256)  590080      max_pooling2d_63[0][0]
# __________________________________________________________________________________________________
# instance_normalization_248 (Ins (None, 32, 12, 256)  512         conv2d_263[0][0]
# __________________________________________________________________________________________________
# re_lu_248 (ReLU)                (None, 32, 12, 256)  0           instance_normalization_248[0][0]
# __________________________________________________________________________________________________
# dropout_248 (Dropout)           (None, 32, 12, 256)  0           re_lu_248[0][0]
# __________________________________________________________________________________________________
# conv2d_264 (Conv2D)             (None, 32, 12, 256)  590080      dropout_248[0][0]
# __________________________________________________________________________________________________
# instance_normalization_249 (Ins (None, 32, 12, 256)  512         conv2d_264[0][0]
# __________________________________________________________________________________________________
# dropout_249 (Dropout)           (None, 32, 12, 256)  0           instance_normalization_249[0][0]
# __________________________________________________________________________________________________
# add_184 (Add)                   (None, 32, 12, 256)  0           instance_normalization_248[0][0]
#                                                                  dropout_249[0][0]
# __________________________________________________________________________________________________
# re_lu_249 (ReLU)                (None, 32, 12, 256)  0           add_184[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_60 (UpSampling2D) (None, 64, 24, 256)  0           re_lu_249[0][0]
# __________________________________________________________________________________________________
# add_185 (Add)                   (None, 64, 24, 256)  0           up_sampling2d_60[0][0]
#                                                                  re_lu_247[0][0]
# __________________________________________________________________________________________________
# conv2d_265 (Conv2D)             (None, 64, 24, 128)  295040      add_185[0][0]
# __________________________________________________________________________________________________
# instance_normalization_250 (Ins (None, 64, 24, 128)  256         conv2d_265[0][0]
# __________________________________________________________________________________________________
# re_lu_250 (ReLU)                (None, 64, 24, 128)  0           instance_normalization_250[0][0]
# __________________________________________________________________________________________________
# dropout_250 (Dropout)           (None, 64, 24, 128)  0           re_lu_250[0][0]
# __________________________________________________________________________________________________
# conv2d_266 (Conv2D)             (None, 64, 24, 128)  147584      dropout_250[0][0]
# __________________________________________________________________________________________________
# instance_normalization_251 (Ins (None, 64, 24, 128)  256         conv2d_266[0][0]
# __________________________________________________________________________________________________
# dropout_251 (Dropout)           (None, 64, 24, 128)  0           instance_normalization_251[0][0]
# __________________________________________________________________________________________________
# add_186 (Add)                   (None, 64, 24, 128)  0           instance_normalization_250[0][0]
#                                                                  dropout_251[0][0]
# __________________________________________________________________________________________________
# re_lu_251 (ReLU)                (None, 64, 24, 128)  0           add_186[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_61 (UpSampling2D) (None, 128, 48, 128) 0           re_lu_251[0][0]
# __________________________________________________________________________________________________
# add_187 (Add)                   (None, 128, 48, 128) 0           up_sampling2d_61[0][0]
#                                                                  re_lu_245[0][0]
# __________________________________________________________________________________________________
# conv2d_267 (Conv2D)             (None, 128, 48, 64)  73792       add_187[0][0]
# __________________________________________________________________________________________________
# instance_normalization_252 (Ins (None, 128, 48, 64)  128         conv2d_267[0][0]
# __________________________________________________________________________________________________
# re_lu_252 (ReLU)                (None, 128, 48, 64)  0           instance_normalization_252[0][0]
# __________________________________________________________________________________________________
# dropout_252 (Dropout)           (None, 128, 48, 64)  0           re_lu_252[0][0]
# __________________________________________________________________________________________________
# conv2d_268 (Conv2D)             (None, 128, 48, 64)  36928       dropout_252[0][0]
# __________________________________________________________________________________________________
# instance_normalization_253 (Ins (None, 128, 48, 64)  128         conv2d_268[0][0]
# __________________________________________________________________________________________________
# dropout_253 (Dropout)           (None, 128, 48, 64)  0           instance_normalization_253[0][0]
# __________________________________________________________________________________________________
# add_188 (Add)                   (None, 128, 48, 64)  0           instance_normalization_252[0][0]
#                                                                  dropout_253[0][0]
# __________________________________________________________________________________________________
# re_lu_253 (ReLU)                (None, 128, 48, 64)  0           add_188[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_62 (UpSampling2D) (None, 256, 96, 64)  0           re_lu_253[0][0]
# __________________________________________________________________________________________________
# add_189 (Add)                   (None, 256, 96, 64)  0           up_sampling2d_62[0][0]
#                                                                  re_lu_243[0][0]
# __________________________________________________________________________________________________
# conv2d_269 (Conv2D)             (None, 256, 96, 32)  18464       add_189[0][0]
# __________________________________________________________________________________________________
# instance_normalization_254 (Ins (None, 256, 96, 32)  64          conv2d_269[0][0]
# __________________________________________________________________________________________________
# re_lu_254 (ReLU)                (None, 256, 96, 32)  0           instance_normalization_254[0][0]
# __________________________________________________________________________________________________
# dropout_254 (Dropout)           (None, 256, 96, 32)  0           re_lu_254[0][0]
# __________________________________________________________________________________________________
# conv2d_270 (Conv2D)             (None, 256, 96, 32)  9248        dropout_254[0][0]
# __________________________________________________________________________________________________
# instance_normalization_255 (Ins (None, 256, 96, 32)  64          conv2d_270[0][0]
# __________________________________________________________________________________________________
# dropout_255 (Dropout)           (None, 256, 96, 32)  0           instance_normalization_255[0][0]
# __________________________________________________________________________________________________
# add_190 (Add)                   (None, 256, 96, 32)  0           instance_normalization_254[0][0]
#                                                                  dropout_255[0][0]
# __________________________________________________________________________________________________
# re_lu_255 (ReLU)                (None, 256, 96, 32)  0           add_190[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_63 (UpSampling2D) (None, 512, 192, 32) 0           re_lu_255[0][0]
# __________________________________________________________________________________________________
# add_191 (Add)                   (None, 512, 192, 32) 0           up_sampling2d_63[0][0]
#                                                                  re_lu_241[0][0]
# __________________________________________________________________________________________________
# conv2d_271 (Conv2D)             (None, 512, 192, 18) 5202        add_191[0][0]
# __________________________________________________________________________________________________
# data_const_K_u2_2 (Lambda)      (None, 512, 192, 18) 0           input_7[0][0]
#                                                                  conv2d_271[0][0]
# __________________________________________________________________________________________________
# IFT_RSS (Lambda)                (None, 512, 192)     0           data_const_K_u2_2[0][0]
# ==================================================================================================
# Total params: 11,787,336
# Trainable params: 11,787,336
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history=model.fit([x_train,grappa_train_indx], y_train,
            epochs=epochs,
            batch_size=batch_size,
            shuffle=False,
            validation_data=([x_test,grappa_test_indx], y_test),
            callbacks=get_callbacks(model_name,0.6,10,1),
            max_queue_size=32,                # maximum size for the generator queue
            workers=100,
            use_multiprocessing=False
             )

model_json = model.to_json()
with open("weights/model_grappaNet_2.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("weights/model_grappaNet_json.h5")
print("Saved model to disk")
# Out:
#  9/29 [========>.....................] - ETA: 51s - loss: 0.3590 - root_mean_squared_error: 0.1385

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
from tensorflow.keras.models import load_model
#model.load_weights("weights/model_grappaNet.h5")
ex_recons_imgs = model.predict([x_test,grappa_test_indx])
